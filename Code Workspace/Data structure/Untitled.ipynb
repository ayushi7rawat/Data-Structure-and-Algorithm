# %%
s=set()

# %%
s.add(1)

# %%
s
# Out:
# {1}

# %%
s1={1,2,3,3}

# %%
s1
# Out:
# {1, 2, 3}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

z = x.difference(y)

print(z)
# Out:
# {'cherry', 'banana'}

# %%
print(x-y)
# Out:
# {'cherry', 'banana'}

# %%
s1.remove(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-bb1f1aa47ef4> in <module>
# ----> 1 s1.remove(5)
#
# KeyError: 5
